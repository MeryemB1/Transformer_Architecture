# %%
# !pip install --user torchtext
# !pip install --user torchmetrics
# Out:
# Requirement already satisfied: torchtext in c:\users\km_ka\appdata\roaming\python\python39\site-packages (0.16.2)
# Requirement already satisfied: requests in c:\users\km_ka\anaconda3\lib\site-packages (from torchtext) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\km_ka\anaconda3\lib\site-packages (from torchtext) (4.64.1)
# Requirement already satisfied: numpy in c:\users\km_ka\anaconda3\lib\site-packages (from torchtext) (1.26.2)
# Requirement already satisfied: torch==2.1.2 in c:\users\km_ka\anaconda3\lib\site-packages (from torchtext) (2.1.2)
# Requirement already satisfied: torchdata==0.7.1 in c:\users\km_ka\appdata\roaming\python\python39\site-packages (from torchtext) (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (2.11.3)
# Requirement already satisfied: filelock in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (3.6.0)
# Requirement already satisfied: networkx in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (2023.10.0)
# Requirement already satisfied: typing-extensions in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (4.3.0)
# Requirement already satisfied: sympy in c:\users\km_ka\anaconda3\lib\site-packages (from torch==2.1.2->torchtext) (1.10.1)
# Requirement already satisfied: urllib3>=1.25 in c:\users\km_ka\anaconda3\lib\site-packages (from torchdata==0.7.1->torchtext) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\km_ka\anaconda3\lib\site-packages (from requests->torchtext) (2023.11.17)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\km_ka\anaconda3\lib\site-packages (from requests->torchtext) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\km_ka\anaconda3\lib\site-packages (from requests->torchtext) (3.3)
# Requirement already satisfied: colorama in c:\users\km_ka\anaconda3\lib\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\km_ka\anaconda3\lib\site-packages (from jinja2->torch==2.1.2->torchtext) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\km_ka\anaconda3\lib\site-packages (from sympy->torch==2.1.2->torchtext) (1.2.1)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# Requirement already satisfied: torchmetrics in c:\users\km_ka\appdata\roaming\python\python39\site-packages (1.2.1)
# Requirement already satisfied: torch>=1.8.1 in c:\users\km_ka\anaconda3\lib\site-packages (from torchmetrics) (2.1.2)
# Requirement already satisfied: numpy>1.20.0 in c:\users\km_ka\anaconda3\lib\site-packages (from torchmetrics) (1.26.2)
# Requirement already satisfied: packaging>17.1 in c:\users\km_ka\anaconda3\lib\site-packages (from torchmetrics) (21.3)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\km_ka\appdata\roaming\python\python39\site-packages (from torchmetrics) (0.10.0)
# Requirement already satisfied: setuptools in c:\users\km_ka\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (63.4.1)
# Requirement already satisfied: typing-extensions in c:\users\km_ka\anaconda3\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\km_ka\anaconda3\lib\site-packages (from packaging>17.1->torchmetrics) (3.0.9)
# Requirement already satisfied: networkx in c:\users\km_ka\anaconda3\lib\site-packages (from torch>=1.8.1->torchmetrics) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\km_ka\anaconda3\lib\site-packages (from torch>=1.8.1->torchmetrics) (2.11.3)
# Requirement already satisfied: filelock in c:\users\km_ka\anaconda3\lib\site-packages (from torch>=1.8.1->torchmetrics) (3.6.0)
# Requirement already satisfied: fsspec in c:\users\km_ka\anaconda3\lib\site-packages (from torch>=1.8.1->torchmetrics) (2023.10.0)
# Requirement already satisfied: sympy in c:\users\km_ka\anaconda3\lib\site-packages (from torch>=1.8.1->torchmetrics) (1.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\km_ka\anaconda3\lib\site-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\km_ka\anaconda3\lib\site-packages (from sympy->torch>=1.8.1->torchmetrics) (1.2.1)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 8
cfg['preload'] = None
cfg['num_epochs'] = 10

from train import train_model

#train_model(cfg)
# Out:
# C:\Users\km_ka\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import torch
import torch.nn as nn
from model import Transformer
from config import get_config, get_weights_file_path
from train import get_model, get_ds, greedy_decode

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# Definir le device sur lequel travailler (cuda si disponible)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("utiliser le device:", device)
# Out:
# Using device: cpu

# %%
config = get_config()
config['num_epochs'] = 10
config['d_model'] = 256
print(config)
train_dataloader, val_dataloader, vocab_src, vocab_tgt = get_ds(config)
model = get_model(config, vocab_src.get_vocab_size(), vocab_tgt.get_vocab_size()).to(device)
import torch
model_filename = 'tmodel_09.pt'
state = torch.load(model_filename, map_location=torch.device('cpu'))
model.load_state_dict(state['model_state_dict'])
# Out:
# {'batch_size': 8, 'num_epochs': 10, 'lr': 0.0001, 'seq_len': 350, 'd_model': 256, 'datasource': 'opus_books', 'lang_src': 'en', 'lang_tgt': 'it', 'model_folder': 'weights', 'model_basename': 'tmodel_', 'preload': 'latest', 'tokenizer_file': 'tokenizer_{0}.json', 'experiment_name': 'runs/tmodel'}
# Max length of source sentence: 309
# Max length of target sentence: 274
# <All keys matched successfully>

# %%
def load_next_batch():
    # Charger un lot d'échantillons depuis l'ensemble de validation.
    batch = next(iter(val_dataloader))
    encoder_input = batch["encoder_input"].to(device)
    encoder_mask = batch["encoder_mask"].to(device)
    decoder_input = batch["decoder_input"].to(device)
    decoder_mask = batch["decoder_mask"].to(device)

    encoder_input_tokens = [vocab_src.id_to_token(idx) for idx in encoder_input[0].cpu().numpy()]
    decoder_input_tokens = [vocab_tgt.id_to_token(idx) for idx in decoder_input[0].cpu().numpy()]

    # verifier que la taille d'un lot est de 1
    assert encoder_input.size(
        0) == 1, "la taille d'un lot pour la validation doit etre de 1"

    model_out = greedy_decode(
        model, encoder_input, encoder_mask, vocab_src, vocab_tgt, config['seq_len'], device)

    return batch, encoder_input_tokens, decoder_input_tokens

# %%
def mtx2df(m, max_row, max_col, row_tokens, col_tokens):
    return pd.DataFrame(
        [
            (
                r,
                c,
                float(m[r, c]),
                "%.3d %s" % (r, row_tokens[r] if len(row_tokens) > r else "<blank>"),
                "%.3d %s" % (c, col_tokens[c] if len(col_tokens) > c else "<blank>"),
            )
            for r in range(m.shape[0])
            for c in range(m.shape[1])
            if r < max_row and c < max_col
        ],
        columns=["row", "column", "value", "row_token", "col_token"],
    )
def get_attn_map(attn_type: str, layer: int, head: int):
    if attn_type == "encoder":
        attn = model.encoder.layers[layer].self_attention_block.attention_scores
    elif attn_type == "decoder":
        attn = model.decoder.layers[layer].self_attention_block.attention_scores
    elif attn_type == "encoder-decoder":
        attn = model.decoder.layers[layer].cross_attention_block.attention_scores
    return attn[0, head].data

def attn_map(attn_type, layer, head, row_tokens, col_tokens, max_sentence_len):
    df = mtx2df(
        get_attn_map(attn_type, layer, head),
        max_sentence_len,
        max_sentence_len,
        row_tokens,
        col_tokens,
    )
    return (
        alt.Chart(data=df)
        .mark_rect()
        .encode(
            x=alt.X("col_token", axis=alt.Axis(title="")),
            y=alt.Y("row_token", axis=alt.Axis(title="")),
            color="value",
            tooltip=["row", "column", "value", "row_token", "col_token"],
        )
        #.title(f"Layer {layer} Head {head}")
        .properties(height=400, width=400, title=f"Layer {layer} Head {head}")
        .interactive()
    )

def get_all_attention_maps(attn_type: str, layers: list[int], heads: list[int], row_tokens: list, col_tokens, max_sentence_len: int):
    charts = []
    for layer in layers:
        rowCharts = []
        for head in heads:
            rowCharts.append(attn_map(attn_type, layer, head, row_tokens, col_tokens, max_sentence_len))
        charts.append(alt.hconcat(*rowCharts))
    return alt.vconcat(*charts)

# %%
batch, encoder_input_tokens, decoder_input_tokens = load_next_batch()
print(f'Source: {batch["src_text"][0]}')
print(f'Target: {batch["tgt_text"][0]}')
sentence_len = encoder_input_tokens.index("[PAD]")
# Out:
# Source: Going up to a door he closed it, then with fixed gaze and tightly clenched teeth, approached the table, took up his revolver, examined it, turned it to a loaded chamber, and pondered.
# Target: Si avvicinò alla porta e la chiuse; dopo, con uno sguardo fisso e coi denti fortemente stretti, si accostò alla tavola e, presa la rivoltella, la esaminò, la rigirò dalla parte della canna carica e si fece pensieroso.

# %%
# !pip install altair
# Out:
# Collecting altair
#   Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#      ------------------------------------ 996.9/996.9 kB 285.7 kB/s eta 0:00:00
# Requirement already satisfied: toolz in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (0.11.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (1.4.4)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (4.3.0)
# Requirement already satisfied: packaging in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (21.3)
# Requirement already satisfied: jinja2 in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (4.16.0)
# Requirement already satisfied: numpy in c:\users\km_ka\anaconda3\lib\site-packages (from altair) (1.26.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\km_ka\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\km_ka\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\km_ka\anaconda3\lib\site-packages (from pandas>=0.25->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\km_ka\anaconda3\lib\site-packages (from pandas>=0.25->altair) (2022.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\km_ka\anaconda3\lib\site-packages (from jinja2->altair) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\km_ka\anaconda3\lib\site-packages (from packaging->altair) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\km_ka\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->altair) (1.16.0)
# Installing collected packages: altair
# Successfully installed altair-5.2.0
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\km_ka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\km_ka\anaconda3\lib\site-packages)

# %%
layers = [0, 1, 2]
heads = [0, 1, 2, 3, 4, 5, 6, 7]
import altair as alt

# Encodeur Self-Attention
get_all_attention_maps("encoder", layers, heads, encoder_input_tokens, encoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)

# %%
# decodeur Self-Attention
get_all_attention_maps("decoder", layers, heads, decoder_input_tokens, decoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)

# %%
# Encodeur-decodeur Self-Attention
get_all_attention_maps("encoder-decoder", layers, heads, encoder_input_tokens, decoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)
